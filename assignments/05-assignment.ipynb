# %% [markdown]
# # DATASCI 350 - Data Science Computing
#
# ## Assignment 05: A reproducible research note with Quarto
#
# In this assignment you build one small, complete deliverable: a research note called "Coffee and contentment", written in Quarto, that follows every reproducibility habit from lectures 10 and 11. The dataset links coffee consumption, income, and happiness scores for 20 countries between 2010 and 2024. The data is synthetic but plausible: the note is about the machinery, not the findings.
#
# The analysis itself is deliberately simple. All the Python you need appeared in the lecture 11 examples, and where a task needs more, the hint says where to look. What we grade is the document: its structure, its rendering, its citations, and whether someone else could rebuild it.
#
# Warning: an absolute path anywhere in your project (any path containing your username) loses points, as discussed in lecture 10. Use relative paths throughout.
#
# Before you start, confirm that `quarto check` reports a working installation, including TinyTeX for PDFs. If TinyTeX is missing, run `quarto install tinytex` once.
#
# ### Instructions
#
# You must complete this assignment individually. You may use notes, books, and AI tools, but you must submit original work. Any errors introduced by AI tools are your responsibility, so always double-check your answers. Acknowledge all resources used, including input from classmates and AI, in a short note at the end of your submission. If you are unsure about permissible resources or proper acknowledgement, please ask the instructor.
#
# ### Submission
#
# Work in a project folder named `coffee-note`. When you finish, compress the whole folder into `coffee-note.zip` and submit it on Canvas. The zip must contain your `.qmd` source, the rendered HTML and PDF outputs, both parameterised HTML files, your cleaning script, your README, and the data folders. Do not include `_site/` or `.quarto/` folders.
#
# Answer the written questions (tasks 11 and 12) in the answer cells of this notebook and submit the notebook too.

# %% [markdown]
# ### Task 01: the project skeleton
#
# Create a project folder `coffee-note` with the folder layout from lecture 10: `data/raw`, `data/clean`, `scripts`, and `output`, plus an empty `README.md`. Then download the dataset into `data/raw` from the command line:
#
# ```bash
# curl -o data/raw/coffee.csv https://raw.githubusercontent.com/danilofreire/datasci350/main/assignments/data/coffee.csv
# ```
#
# Paste the commands you used into the answer cell. *Hint: one command from lecture 04 creates several nested folders at once.*

# %% [markdown]
# *Commands, code, or written answer here.*

# %% [markdown]
# ### Task 02: the note and its header
#
# Inside `coffee-note`, create `note.qmd` with exactly this metadata: title "Coffee and contentment", your name as author, the date, `format: html` with a table of contents enabled, and an `execute:` block that hides warnings for the whole document.
#
# Below the header, write an introduction: one `##` heading, a short paragraph on what the note examines, a bulleted list of the three variables, and one footnote of your choice. *Hint: the YAML options you need are on the lecture 10 slides "The YAML header" and "The chunk options you will use most".*

# %% [markdown]
# *Commands, code, or written answer here.*

# %% [markdown]
# ### Task 03: a cleaning script
#
# Write `scripts/01-clean.py`. It must read `data/raw/coffee.csv`, keep only the years 2015 to 2024, and write the result to `data/clean/coffee-recent.csv`. Run it from the command line, from the project root:
#
# ```bash
# python scripts/01-clean.py
# ```
#
# Paste the script into the answer cell. The raw file stays untouched. *Hint: `pandas` reads and writes CSVs with two functions whose names you can guess; filtering rows was in the lecture 11 report example.*

# %% [markdown]
# *Commands, code, or written answer here.*

# %% [markdown]
# ### Task 04: load the clean data
#
# Add a chunk to `note.qmd` that loads `data/clean/coffee-recent.csv` with a relative path. The chunk must not show its code or any output in the rendered document. *Hint: one chunk option does both at once; it is in the lecture 10 options table.*

# %% [markdown]
# *Commands, code, or written answer here.*

# %% [markdown]
# ### Task 05: a cross-referenced table
#
# Add a table of mean coffee consumption and mean happiness by country, sorted by coffee consumption, highest first. Give the chunk a label starting with `tbl-` and a caption, and reference the table in your prose with `@tbl-...` so it renders as a numbered link.

# %% [markdown]
# *Commands, code, or written answer here.*

# %% [markdown]
# ### Task 06: a cross-referenced figure
#
# Add a scatter plot of coffee consumption against happiness score. Give the chunk a `fig-` label and a `fig-cap` caption, and reference it in your prose with `@fig-...`. One sentence of honest commentary is welcome: the note should not claim that coffee causes happiness.

# %% [markdown]
# *Commands, code, or written answer here.*

# %% [markdown]
# ### Task 07: numbers that update themselves
#
# Somewhere in your prose, report the number of rows in the clean dataset and the overall mean happiness score using inline code, so both numbers change if the data changes. No hard-typed numbers. *Hint: inline code appeared in the lecture 11 slide "A worked example: report.qmd". If a number prints as `np.float64(...)`, wrap it in `float()` before rounding.*

# %% [markdown]
# *Commands, code, or written answer here.*

# %% [markdown]
# ### Task 08: citations
#
# Create `references.bib` in the project root with exactly these three entries:
#
# ```bibtex
# @article{marlowe2023coffee,
#   title={Coffee consumption and subjective wellbeing in high-income countries},
#   author={Marlowe, Ada and Chen, Ruth},
#   journal={Journal of Beverage Economics},
#   volume={18},
#   number={2},
#   pages={101--119},
#   year={2023}
# }
#
# @book{okafor2021brew,
#   title={The Global Brew: An Economic History of Coffee},
#   author={Okafor, Chidi},
#   publisher={Meridian Press},
#   address={London},
#   year={2021}
# }
#
# @article{silva2024caffeine,
#   title={Caffeine, mood, and productivity: a review},
#   author={Silva, Beatriz and Haugen, Lars},
#   journal={Review of Behavioural Nutrition},
#   volume={9},
#   number={1},
#   pages={44--61},
#   year={2024}
# }
# ```
#
# (The references are invented for this assignment; do not look for the papers.) Point the YAML at the file, then cite Marlowe and Chen in the flow of a sentence, and cite Okafor in parentheses with page 12. The reference list must appear at the end of the rendered note.

# %% [markdown]
# *Commands, code, or written answer here.*

# %% [markdown]
# ### Task 09: render twice
#
# Render `note.qmd` to HTML and to PDF from the command line. Both files stay in the project folder for submission. Paste the two commands into the answer cell. If the PDF render fails, read the error before anything else: the usual cause is a missing TinyTeX.

# %% [markdown]
# *Commands, code, or written answer here.*

# %% [markdown]
# ### Task 10: parameterise the note
#
# Add a parameter `country` with the default value `"Finland"` in a cell tagged `parameters`, and add a short section "Country in focus" that filters the clean data to that country and reports, using inline code, the country's name and its mean happiness score.
#
# Then render two versions from the command line, with output names `note-finland.html` and `note-brazil.html`, passing `Finland` and `Brazil` as the parameter. Paste both commands into the answer cell. *Hint: the flag that overrides a parameter and the flag that renames the output are both on the lecture 11 parameterised-reports slides.*

# %% [markdown]
# *Commands, code, or written answer here.*

# %% [markdown]
# ### Task 11: freeze
#
# `freeze` only works inside a Quarto project, so first turn your folder into one: create `_quarto.yml` in the project root with a `project:` block of type `default` and an `execute:` block containing `freeze: auto`. Render the note twice in a row and watch the second run. In the answer cell, explain in no more than two sentences what the second render did and did not do, and where the stored results live.

# %% [markdown]
# *Commands, code, or written answer here.*

# %% [markdown]
# ### Task 12: the README and the self-audit
#
# Complete `README.md` so that a stranger could rebuild your project: one line on what the note is, the data source with the date you downloaded it, the exact commands to rebuild everything in order, and the Python and package versions you used.
#
# Then, in the answer cell, in no more than 80 words: which reproducibility habits from lecture 10 does your submission satisfy, and which one is weakest?

# %% [markdown]
# *Commands, code, or written answer here.*
