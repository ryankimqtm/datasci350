# %% [markdown]
# # DATASCI 350 - Data Science Computing
#
# ## Assignment 03: Git and GitHub
#
# In this assignment, you will build a small public repository from scratch: a personal reading list. You will practise the Git commands from lectures 05 to 07 and the GitHub workflow from lecture 06.
#
# Work through the tasks in order. Use the exact commit messages and branch names given in each task: the grader checks your commit history against them.
#
# Your submission has two parts:
#
# 1. The URL of your public GitHub repository.
# 2. This notebook (or a PDF) with the command(s) you used for each task, plus a screenshot where the task asks for one.
#
# Important: the grader reads your commit history on GitHub. Create and edit files from the command line, not through the GitHub website. Files uploaded through the website lose points.
#
# ### Instructions
#
# You must complete this assignment individually. You may use notes, books, and AI tools, but you must submit original work. Any errors introduced by AI tools are your responsibility, so always double-check your answers. Acknowledge all resources used, including input from classmates and AI, in a short note at the end of your submission. If you are unsure about permissible resources or proper acknowledgement, please ask the instructor.
#
# ### Submission
#
# Submit the notebook (or PDF) and your repository URL to Canvas.

# %% [markdown]
# ### Task 01
#
# Create a directory named `reading-list` and move into it. Initialise it as a Git repository and run `git status`. In one sentence: what does "untracked" mean in the output?

# %% [markdown]
# *Commands, answer, and screenshot (where asked) here.*

# %% [markdown]
# ![image.png](attachment:image.png)
#
# untracked means Git sees a file in the folder, but the file has not been added to Git yet.
#
# mkdir reading-list
#
# cd reading-list
#
# git init
#
# git status

# %% [markdown]
# ### Task 02
#
# Create `README.md` containing the line `# My reading list`, using `echo` and a redirect. Stage that specific file (not with `git add .`) and commit with the message "Add README".

# %% [markdown]
# *Commands, answer, and screenshot (where asked) here.*

# %% [markdown]
# ![image.png](attachment:image.png)
#
# echo "# My reading list" > README.md
#
# git add README.md
#
# git commit -m "Add README"

# %% [markdown]
# ### Task 03
#
# Run `git log` and then `git log --oneline`. In two sentences: what information does each line of the `--oneline` output show, and how does it identify a commit?

# %% [markdown]
# ![image.png](attachment:image.png)
#
# the commit is shortened for git log --oneline with the hash being reduced to 7 characters. each line shows hash and commit message

# %% [markdown]
# ### Task 04
#
# Create a `.gitignore` file with two lines: `drafts/` and `*.tmp`. Then create the directory `drafts` and an empty file `drafts/ideas.tmp` inside it. Run `git status` and take a screenshot showing that Git ignores them. Commit `.gitignore` with the message "Add gitignore".

# %% [markdown]
# ![Screenshot 2026-09-24 223327.png](<attachment:Screenshot 2026-09-24 223327.png>)
#
# ![Screenshot 2026-09-24 223339.png](<attachment:Screenshot 2026-09-24 223339.png>)
#
# echo "drafts/" > .gitignore
#
# echo "*.tmp" >> .gitignore
#
# mkdir drafts
#
# touch drafts/ideas.tmp
#
# git status

# %% [markdown]
# ### Task 05
#
# Create and switch to a branch named `recommendations` in a single command. On it, create `books/recommendations.md` with two book entries (any two books you like, one per line). Commit with the message "Add recommendations".

# %% [markdown]
# ![image.png](attachment:image.png)
#
# git switch -c recommendations
#
# mkdir books
#
# echo "The Woman Warrior" > books/recommendations.md
#
# echo "Interior Chinatown" >> books/recommendations.md
#
# git add books/recommendations.md
#
# git commit -m "Add recommendations"

# %% [markdown]
# ### Task 06
#
# Switch back to `main` and merge `recommendations`. Delete the merged branch. Show the branch list before and after the deletion, with a screenshot of each.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# git switch main
#
# git merge recommendations
#
# git branch
#
# git branch -d recommendations
#
# git branch

# %% [markdown]
# ### Task 07
#
# Create a new public repository named `reading-list` on GitHub (do not initialise it with a README). Connect your local repository to it with `git remote add origin`, then push with `git push -u origin main`. In one sentence: what does the `-u` flag do? Paste your repository URL here.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# https://github.com/ryankimqtm/readi
# ng-list.git
#
# I think the -u flag connects my local main branch to the main branch on GitHub so future changes are easier

# %% [markdown]
# ### Task 08
#
# Create and switch to a branch named `more-books`. Add two more titles to `books/recommendations.md`. Commit with the message "Add two novels" and push the branch to GitHub. On GitHub, open a pull request titled "Add two novels" and merge it with a merge commit. Back in your terminal, switch to `main` and run `git pull`. Take a screenshot of the merged pull request page.

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# git switch -c more-books
#
# echo "Pachinko" >> books/recommendations.md
#
# echo "The Namesake" >> books/recommendations.md
#
# git add books/recommendations.md
#
# git commit -m "Add two novels"
#
# git push -u origin more-books

# %% [markdown]
# ### Task 09
#
# Append one more title to `README.md` and commit with the message "Add boks" (with this exact typo). Then fix the message with a single command so it reads "Add books". In one sentence: why should you not do this to a commit you have already pushed?

# %% [markdown]
# ![image.png](attachment:image.png)
#
# I think you should not change a commit after pushing it because it can mess up the shared Git history.
#
# echo "Crying in H Mart" >> README.md
#
# git add README.md
#
# git commit -m "Add boks"
#
# git commit --amend -m "Add books"

# %% [markdown]
# ### Task 10
#
# Modify `README.md` (change any line). Before staging, run `git diff` and take a screenshot. In two sentences: what do the lines starting with `-` and `+` mean? Then stage and commit with the message "Update README".

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Lines starting with - show what was removed or changed from the old version and lines starting with + show what was added in new version.
#
# echo "# My updated reading list" > README.md
#
# git diff
#
# git add README.md
#
# git commit -m "Update README"

# %% [markdown]
# ### Task 11
#
# On GitHub, open an issue in your `reading-list` repository titled "Add five more books", with a one-line description of the idea. Issues let you track plans for a project without changing any files. Paste the issue's URL here.

# %% [markdown]
# (https://github.com/ryankimqtm/reading-list/issues/2#issue-5577443494)

# %% [markdown]
# ### Task 12
#
# In two or three sentences: what is the difference between cloning a repository and forking it? Give one situation where you need a fork.

# %% [markdown]
# Cloning makes a copy of a repository on your computer. Forking makes your own copy of someone else’s repository on GitHub. You need a fork when you want to make changes to someone else’s project without changing their original repository.
